# %% [markdown]
# # Set up #
# Set up all the packages before getting started. Simply run the cell below to set up the packages

# %%
# data processing package
# !pip install pandas
# !pip install numpy

# visualization package
# !pip install matplotlib

# learning package to help guide you if needed
# !pip install learntools

# ML/DL packages
# !pip install sklearn
# !pip install tensorflow
# !pip install keras

# %%
import pandas
import matplotlib
import learntools
import tensorflow
import keras
